# %%
# imports

import pandas as pd
import re

# %%
# functions

def drop_sparse_columns(df):
    column_names = df.columns.values
    for name in column_names:
        try:
            if df[name].isnull().sum() > 100000:
                df.drop(labels=name, axis=1, inplace=True)
        except ValueError:
            pass
    return df    


def filter_set_status(df):
    def set_status(s):
        if s == 'Fully Paid':
            return 'Paid'
        if s == 'Charged Off':
            return 'Not Paid'
        if s == 'Default':
            return 'Not Paid'
        if s == 'Does not meet the credit policy. Status:Fully Paid':
            return 'Paid'
        if s == 'Does not meet the credit policy. Status:Charged Off':
            return 'Paid'
       
    df = df[(df['loan_status'] == 'Fully Paid') | (df['loan_status'] == 'Charged Off') |
            (df['loan_status'] == 'Default')]  
    
    df['loan_status'] = df['loan_status'].apply(set_status)  
    return df

# %%
# columns 19 and 55 have mixed data types so we force them to strings for now
loan_df = pd.read_csv('loan.csv', dtype={19:'str', 55:'str'})

# %% [markdown]
# ## General Info

# %%
print "Number of observations: %s" % loan_df.shape[0]
print "Number of columns: %s" % loan_df.shape[1]
# Out:
# Number of observations: 887379
# Number of columns: 74

# %% [markdown]
# ## Response Variable
#
# This variable is `loan_status`. The possible values of this variable are

# %%
loan_df['loan_status'].unique()
# Out:
# array(['Fully Paid', 'Charged Off', 'Current', 'Default',
#        'Late (31-120 days)', 'In Grace Period', 'Late (16-30 days)',
#        'Does not meet the credit policy. Status:Fully Paid',
#        'Does not meet the credit policy. Status:Charged Off', 'Issued'], dtype=object)

# %% [markdown]
# It is probably prudent to simplify these categories. First let's define them (https://help.lendingclub.com/hc/en-us/articles/215488038-What-do-the-different-Note-statuses-mean-):
#
# - Fully Paid : Fully Paid
# - Charged Off : Loan past due for at least 121 days but not more than 151 days.
# - Current : All payments made on time to date
# - Default : Loan past due for 121 days.
# - Late (31-120 days) :
# - In Grace Period : This is late 1-15 days I think.
# - Late (16-30 days) :
# - Does not meet the credit policy. Status:Fully Paid : From what I can tell, LC policy changed since loan origination.
# - Does not meet the credit policy. Status:Charged Off : But status is still correct.
# - Issued : Loan has been issued.
#
# Now, the important thing to be able to predict is which loans will default. Perhaps we can even assign a probability of default to the prediction. It seems we will have to filter some of the data since we don't know whether someone who is 1-120 days late will actually default. We also don't know if someone who is current will actually make all payments. It makes sense to map as follows:
#
# - Fully Paid => Paid
# - Charged off, Default => Not Paid
#
# For the columns that begin with "Does not meet..." we will use the status. We may also want to include Late 31-120 days in the default category. We should perhaps try it both ways and compare our accuracy.

# %%
loan_df =  filter_set_status(loan_df)
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## Cleaning

# %%
loan_df.shape
# Out:
# (254190, 74)

# %%
loan_df.columns.values
# Out:
# array(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'desc', 'purpose', 'zip_code',
#        'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line',
#        'inq_last_6mths', 'mths_since_last_delinq',
#        'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'initial_list_status',
#        'last_credit_pull_d', 'collections_12_mths_ex_med',
#        'mths_since_last_major_derog', 'policy_code', 'application_type',
#        'annual_inc_joint', 'dti_joint', 'verification_status_joint',
#        'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m',
#        'open_il_6m', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il',
#        'total_bal_il', 'il_util', 'open_rv_12m', 'open_rv_24m',
#        'max_bal_bc', 'all_util', 'total_rev_hi_lim', 'inq_fi',
#        'total_cu_tl', 'inq_last_12m'], dtype=object)

# %%
# There are some columns we should drop
loan_df.drop(labels=['collection_recovery_fee',
                    'last_pymnt_amnt',
                    'last_pymnt_d',
                    'next_pymnt_d',
                    'out_prncp',
                    'out_prncp_inv',
                    'pymnt_plan',
                    'recoveries',
                    'term',
                    'title',
                    'total_pymnt',
                    'total_pymnt_inv',
                    'total_rec_int',
                    'total_rec_late_fee',
                    'total_rec_prncp',
                    'url'], axis=1, inplace=True)

# %% [markdown]
# loan_df = drop_sparse_columns(loan_df)

# %%
loan_df.iloc[:, 0:12].describe(include='all')
# Out:
#                   id     member_id      loan_amnt    funded_amnt  \
# count   2.541900e+05  2.541900e+05  254190.000000  254190.000000
# unique           NaN           NaN            NaN            NaN
# top              NaN           NaN            NaN            NaN
# freq             NaN           NaN            NaN            NaN
# mean    1.234067e+07  1.366169e+07   13570.590897   13530.210374
# std     1.479726e+07  1.576494e+07    8133.386869    8111.020870
# min     5.473400e+04  7.069900e+04     500.000000     500.000000
# 25%     1.462514e+06  1.709671e+06    7250.000000    7200.000000
# 50%     6.321818e+06  7.660992e+06   12000.000000   12000.000000
# 75%     1.655208e+07  1.858534e+07   18250.000000   18125.000000
# max     6.860466e+07  7.350742e+07   35000.000000   35000.000000
#
#         funded_amnt_inv       int_rate    installment   grade sub_grade  \
# count     254190.000000  254190.000000  254190.000000  254190    254190
# unique              NaN            NaN            NaN       7        35
# top                 NaN            NaN            NaN       B        B3
# freq                NaN            NaN            NaN   76263     18106
# mean       13437.613928      13.776014     418.273195     NaN       NaN
# std         8129.476448       4.404088     244.912615     NaN       NaN
# min            0.000000       5.320000      15.690000     NaN       NaN
# 25%         7200.000000      10.740000     239.560000     NaN       NaN
# 50%        11975.000000      13.530000     365.230000     NaN       NaN
# 75%        18000.000000      16.550000     547.550000     NaN       NaN
# max        35000.000000      28.990000    1424.570000     NaN       NaN
#
#        emp_title
# count     240183
# unique    133191
# top      Manager
# freq        1959
# mean         NaN
# std          NaN
# min          NaN
# 25%          NaN
# 50%          NaN
# 75%          NaN
# max          NaN

# %%
loan_df.iloc[:, 13:25].describe(include='all')
# Out:
#        verification_status   issue_d loan_status             purpose zip_code  \
# count               254190    254190      254190              254190   254190
# unique                   3       103           2                  14      886
# top               Verified  Oct-2014        Paid  debt_consolidation    945xx
# freq                 93375      8808      207723              149153     3303
# mean                   NaN       NaN         NaN                 NaN      NaN
# std                    NaN       NaN         NaN                 NaN      NaN
# min                    NaN       NaN         NaN                 NaN      NaN
# 25%                    NaN       NaN         NaN                 NaN      NaN
# 50%                    NaN       NaN         NaN                 NaN      NaN
# 75%                    NaN       NaN         NaN                 NaN      NaN
# max                    NaN       NaN         NaN                 NaN      NaN
#
#        addr_state            dti    delinq_2yrs earliest_cr_line  \
# count      254190  254190.000000  254190.000000           254190
# unique         51            NaN            NaN              645
# top            CA            NaN            NaN         Oct-2000
# freq        43321            NaN            NaN             2119
# mean          NaN      16.560534       0.250533              NaN
# std           NaN       7.794390       0.742390              NaN
# min           NaN       0.000000       0.000000              NaN
# 25%           NaN      10.770000       0.000000              NaN
# 50%           NaN      16.220000       0.000000              NaN
# 75%           NaN      22.010000       0.000000              NaN
# max           NaN      57.140000      29.000000              NaN
#
#         inq_last_6mths       open_acc        pub_rec
# count    254190.000000  254190.000000  254190.000000
# unique             NaN            NaN            NaN
# top                NaN            NaN            NaN
# freq               NaN            NaN            NaN
# mean          0.852508      10.944227       0.143794
# std           1.067088       4.893242       0.436923
# min           0.000000       0.000000       0.000000
# 25%           0.000000       7.000000       0.000000
# 50%           1.000000      10.000000       0.000000
# 75%           1.000000      14.000000       0.000000
# max           8.000000      76.000000      15.000000

# %%
loan_df.iloc[:, 26:].describe(include='all')
# Out:
#            revol_util      total_acc initial_list_status last_credit_pull_d  \
# count   253990.000000  254190.000000              254190             254169
# unique            NaN            NaN                   2                102
# top               NaN            NaN                   f           Jan-2016
# freq              NaN            NaN              182747             103213
# mean        54.330606      25.037291                 NaN                NaN
# std         24.785064      11.749435                 NaN                NaN
# min          0.000000       2.000000                 NaN                NaN
# 25%         36.300000      16.000000                 NaN                NaN
# 50%         55.800000      23.000000                 NaN                NaN
# 75%         73.900000      32.000000                 NaN                NaN
# max        892.300000     150.000000                 NaN                NaN
#
#         collections_12_mths_ex_med  policy_code application_type  \
# count                254134.000000     254190.0           254190
# unique                         NaN          NaN                2
# top                            NaN          NaN       INDIVIDUAL
# freq                           NaN          NaN           254189
# mean                      0.006772          1.0              NaN
# std                       0.089273          0.0              NaN
# min                       0.000000          1.0              NaN
# 25%                       0.000000          1.0              NaN
# 50%                       0.000000          1.0              NaN
# 75%                       0.000000          1.0              NaN
# max                       6.000000          1.0              NaN
#
#         acc_now_delinq  tot_coll_amt   tot_cur_bal  total_rev_hi_lim
# count    254190.000000  1.904640e+05  1.904640e+05      1.904640e+05
# unique             NaN           NaN           NaN               NaN
# top                NaN           NaN           NaN               NaN
# freq               NaN           NaN           NaN               NaN
# mean          0.003124  2.033825e+02  1.381605e+05      2.969485e+04
# std           0.060602  2.103550e+04  1.523284e+05      2.949980e+04
# min           0.000000  0.000000e+00  0.000000e+00      0.000000e+00
# 25%           0.000000  0.000000e+00  2.835575e+04      1.330000e+04
# 50%           0.000000  0.000000e+00  8.076050e+04      2.230000e+04
# 75%           0.000000  0.000000e+00  2.079905e+05      3.680000e+04
# max           5.000000  9.152545e+06  8.000078e+06      2.013133e+06

# %%
loan_df.shape
# Out:
# (254190, 37)

# %% [markdown]
# So we have removed columns with more than 100,000 missing values. We have also removed columns for extraneous reasons. Now of the columns left some comments:
#
# - Employee title has 240,183 values of which 133,191 are Manager
# - revol_util has only 253,990 values
# - last_credit_pull_d has only 254,196 values
# - collections_12_mths_ex_med has only
